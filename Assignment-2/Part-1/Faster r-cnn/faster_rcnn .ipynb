# %% [markdown]
# # Part-1
# - Object Detection Using Faster-rcnn
# - Group number S21DL20
# -  Team members
#    - Korupoulu Saideepthi    S20180010087
#    - Varakala Sowmya         S20180010187
#    - Manjju Shree Devy       S20180010055
#    - Swathi Kedarasetty      S20180010172

# %% [markdown]
# ## Mounting to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/faster-rcnn"
# Out:
# /content/drive/MyDrive/faster-rcnn

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Installing necessary libraries

# %%
# !pip install tqdm
# !pip install tensorboardX
# !pip install opencv-python~=3.4
# Out:
# ...
#      |████████████████████████████████| 122kB 17.2MB/s
# ...
#      |████████████████████████████████| 48.6MB 58kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %% [markdown]
# ## Training

# %%
# !python train.py -s=voc2007 -b=resnet101
# Out:
# 2021-04-11 05:42:56 INFO     Arguments:
# 2021-04-11 05:42:56 INFO     	dataset = voc2007
# 2021-04-11 05:42:56 INFO     	backbone = resnet101
# 2021-04-11 05:42:56 INFO     	data_dir = ./data
# 2021-04-11 05:42:56 INFO     	outputs_dir = ./outputs
# 2021-04-11 05:42:56 INFO     	resume_checkpoint = None
# 2021-04-11 05:42:56 INFO     	image_min_side = None
# 2021-04-11 05:42:56 INFO     	image_max_side = None
# 2021-04-11 05:42:56 INFO     	anchor_ratios = None
# 2021-04-11 05:42:56 INFO     	anchor_sizes = None
# 2021-04-11 05:42:56 INFO     	pooler_mode = None
# 2021-04-11 05:42:56 INFO     	rpn_pre_nms_top_n = None
# 2021-04-11 05:42:56 INFO     	rpn_post_nms_top_n = None
# 2021-04-11 05:42:56 INFO     	anchor_smooth_l1_loss_beta = None
# 2021-04-11 05:42:56 INFO     	proposal_smooth_l1_loss_beta = None
# 2021-04-11 05:42:56 INFO     	batch_size = None
# 2021-04-11 05:42:56 INFO     	learning_rate = None
# 2021-04-11 05:42:56 INFO     	momentum = None
# ...

# %% [markdown]
# ## Testing

# %%
# !python eval.py -s=voc2007 -b=resnet101 '/content/drive/MyDrive/faster-rcnn/outputs/checkpoints-20210411054256-voc2007-resnet101-e4ff7f19/model-20000.pth'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2021-04-14 08:48:31 INFO     Found 2510 samples
# 2021-04-14 08:48:36 INFO     Start evaluating with 1 GPU (1 batch per GPU)
# 100% 2510/2510 [05:15<00:00,  7.97it/s]
# 2021-04-14 08:53:59 INFO     Done
# 2021-04-14 08:53:59 INFO     mean AP = :0.4316
# 1: aeroplane AP = 0.5056
# 2: bicycle AP = 0.0462
# 3: bird AP = 0.6708
# 4: boat AP = 0.4821
# 5: bottle AP = 0.2817
# 6: bus AP = 0.5478
# 7: car AP = 0.1867
# 8: cat AP = 0.4620
# 9: chair AP = 0.5142
# 10: cow AP = 0.6853
# 11: diningtable AP = 0.3388
# 12: dog AP = 0.5429
# ...

# %% [markdown]
# ## References
#  - https://www.youtube.com/watch?v=iHf2xHQ2VYo&t=148s
#  - https://blog.paperspace.com/faster-r-cnn-explained-object-detection/
