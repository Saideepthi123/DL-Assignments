# %% [markdown]
# # Assignment 1 Part 3A Introduction: Multi-label Image Classification
#
# ###### SAI DEEPTHI
# ###### SOWMYA
# ###### MANJJU SHREE
# ###### SWATHI

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install torch==1.5 torchvision==0.6
# Out:
# Collecting torch==1.5
#   Downloading https://files.pythonhosted.org/packages/76/58/668ffb25215b3f8231a550a227be7f905f514859c70a65ca59d28f9b7f60/torch-1.5.0-cp37-cp37m-manylinux1_x86_64.whl (752.0MB)
#      |████████████████████████████████| 752.0MB 25kB/s
# Collecting torchvision==0.6
#   Downloading https://files.pythonhosted.org/packages/7b/ed/a894f274a7733d6492e438a5831a95b507c5ec777edf6d8c3b97574e08c4/torchvision-0.6.0-cp37-cp37m-manylinux1_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 20.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.5) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.5) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.6) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.1+cu101
#     Uninstalling torch-1.7.1+cu101:
#       Successfully uninstalled torch-1.7.1+cu101
#   Found existing installation: torchvision 0.8.2+cu101
#     Uninstalling torchvision-0.8.2+cu101:
#       Successfully uninstalled torchvision-0.8.2+cu101
# Successfully installed torch-1.5.0 torchvision-0.6.0

# %%
# %cd '/content/drive/MyDrive/DL/assignment1-part3/assignment1-part3'
# Out:
# /content/drive/MyDrive/DL/assignment1-part3/assignment1-part3

# %%
# !ls
# Out:
# A1_P3A_Introduction.ipynb	 classifier.py	   voc_dataloader.py
# A1_P3B_Develop_Classifier.ipynb  download_data.sh  VOCdevkit

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 3A
# You will use this notebook to warm up with pytorch.
#
# ### What to do
# In part 3A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 3A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 3A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('VOCdevkit/VOC2007','train',train_transform)
# Out:
# /content/drive/MyDrive/DL/assignment1-part3/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# !mv "/content/drive/MyDrive/DL/assignment1-part3/assignment1-part3/VOCdevkit/VOCdevkit/VOC2007test" "/content/drive/MyDrive/DL/assignment1-part3/assignment1-part3/VOCdevkit"

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('VOCdevkit/VOC2007','val',test_transform)
# Out:
# /content/drive/MyDrive/DL/assignment1-part3/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('VOCdevkit/VOC2007', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5333188772201538
# -------  Class: aeroplane        AP:   0.1535  -------
# -------  Class: bicycle          AP:   0.0530  -------
# -------  Class: bird             AP:   0.1096  -------
# -------  Class: boat             AP:   0.1278  -------
# -------  Class: bottle           AP:   0.0367  -------
# -------  Class: bus              AP:   0.0337  -------
# -------  Class: car              AP:   0.1229  -------
# -------  Class: cat              AP:   0.0769  -------
# -------  Class: chair            AP:   0.1068  -------
# -------  Class: cow              AP:   0.0308  -------
# -------  Class: diningtable      AP:   0.0434  -------
# -------  Class: dog              AP:   0.1119  -------
# -------  Class: horse            AP:   0.0507  -------
# -------  Class: motorbike        AP:   0.0485  -------
# -------  Class: person           AP:   0.3548  -------
# -------  Class: pottedplant      AP:   0.0433  -------
# -------  Class: sheep            AP:   0.0245  -------
# -------  Class: sofa             AP:   0.0760  -------
# -------  Class: train            AP:   0.0375  -------
# -------  Class: tvmonitor        AP:   0.0501  -------
# mAP: 0.0846
# Avg loss: 0.2644976073620366
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08462171311683418
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2484472393989563
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2457156479358673
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24608813226222992
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24063526093959808
# -------  Class: aeroplane        AP:   0.0819  -------
# -------  Class: bicycle          AP:   0.0468  -------
# -------  Class: bird             AP:   0.1094  -------
# -------  Class: boat             AP:   0.0771  -------
# -------  Class: bottle           AP:   0.0443  -------
# -------  Class: bus              AP:   0.0295  -------
# -------  Class: car              AP:   0.1157  -------
# -------  Class: cat              AP:   0.1014  -------
# -------  Class: chair            AP:   0.1314  -------
# -------  Class: cow              AP:   0.0305  -------
# -------  Class: diningtable      AP:   0.0540  -------
# -------  Class: dog              AP:   0.1316  -------
# -------  Class: horse            AP:   0.0503  -------
# -------  Class: motorbike        AP:   0.0433  -------
# -------  Class: person           AP:   0.3988  -------
# -------  Class: pottedplant      AP:   0.0471  -------
# -------  Class: sheep            AP:   0.0279  -------
# -------  Class: sofa             AP:   0.1059  -------
# -------  Class: train            AP:   0.0371  -------
# -------  Class: tvmonitor        AP:   0.0545  -------
# mAP: 0.0859
# Avg loss: 0.2356057029728796
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08593187969408247
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.2428673803806305
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.24123737215995789
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.23533780872821808
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2385561466217041
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2352362722158432
# -------  Class: aeroplane        AP:   0.1596  -------
# -------  Class: bicycle          AP:   0.0553  -------
# -------  Class: bird             AP:   0.1189  -------
# -------  Class: boat             AP:   0.1074  -------
# -------  Class: bottle           AP:   0.0556  -------
# -------  Class: bus              AP:   0.0472  -------
# -------  Class: car              AP:   0.1612  -------
# -------  Class: cat              AP:   0.1171  -------
# -------  Class: chair            AP:   0.1706  -------
# -------  Class: cow              AP:   0.0315  -------
# -------  Class: diningtable      AP:   0.0664  -------
# -------  Class: dog              AP:   0.1369  -------
# -------  Class: horse            AP:   0.0547  -------
# -------  Class: motorbike        AP:   0.0430  -------
# -------  Class: person           AP:   0.4730  -------
# -------  Class: pottedplant      AP:   0.0470  -------
# -------  Class: sheep            AP:   0.0332  -------
# -------  Class: sofa             AP:   0.1310  -------
# -------  Class: train            AP:   0.0582  -------
# -------  Class: tvmonitor        AP:   0.0614  -------
# mAP: 0.1065
# Avg loss: 0.2318139403474097
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.10646533710528146
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2321373075246811
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.23106521368026733
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.22819209098815918
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.22722382843494415
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.2235068678855896
# -------  Class: aeroplane        AP:   0.2722  -------
# -------  Class: bicycle          AP:   0.0626  -------
# -------  Class: bird             AP:   0.1170  -------
# -------  Class: boat             AP:   0.2113  -------
# -------  Class: bottle           AP:   0.0736  -------
# -------  Class: bus              AP:   0.0659  -------
# -------  Class: car              AP:   0.1755  -------
# -------  Class: cat              AP:   0.1241  -------
# -------  Class: chair            AP:   0.2124  -------
# -------  Class: cow              AP:   0.0345  -------
# -------  Class: diningtable      AP:   0.1125  -------
# -------  Class: dog              AP:   0.1483  -------
# -------  Class: horse            AP:   0.0809  -------
# -------  Class: motorbike        AP:   0.0476  -------
# -------  Class: person           AP:   0.4812  -------
# -------  Class: pottedplant      AP:   0.0601  -------
# -------  Class: sheep            AP:   0.0404  -------
# -------  Class: sofa             AP:   0.1679  -------
# -------  Class: train            AP:   0.1034  -------
# -------  Class: tvmonitor        AP:   0.0770  -------
# mAP: 0.1334
# Avg loss: 0.22472374199652204
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.13341613896014134
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.22485363483428955
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.2232775092124939
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.22193965315818787
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.22170685231685638
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.21951650083065033
# -------  Class: aeroplane        AP:   0.3323  -------
# -------  Class: bicycle          AP:   0.0630  -------
# -------  Class: bird             AP:   0.1024  -------
# -------  Class: boat             AP:   0.2209  -------
# -------  Class: bottle           AP:   0.0852  -------
# -------  Class: bus              AP:   0.0733  -------
# -------  Class: car              AP:   0.2155  -------
# -------  Class: cat              AP:   0.1298  -------
# -------  Class: chair            AP:   0.2427  -------
# -------  Class: cow              AP:   0.0417  -------
# -------  Class: diningtable      AP:   0.1561  -------
# -------  Class: dog              AP:   0.1447  -------
# -------  Class: horse            AP:   0.1206  -------
# -------  Class: motorbike        AP:   0.0651  -------
# -------  Class: person           AP:   0.4924  -------
# -------  Class: pottedplant      AP:   0.0705  -------
# -------  Class: sheep            AP:   0.0492  -------
# -------  Class: sofa             AP:   0.1878  -------
# -------  Class: train            AP:   0.1360  -------
# -------  Class: tvmonitor        AP:   0.1040  -------
# mAP: 0.1517
# Avg loss: 0.22191078201228498
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.151676615696167

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('VOCdevkit/VOC2007test','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# /content/drive/MyDrive/DL/assignment1-part3/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order
# -------  Class: aeroplane        AP:   0.3091  -------
# -------  Class: bicycle          AP:   0.0617  -------
# -------  Class: bird             AP:   0.1078  -------
# -------  Class: boat             AP:   0.1859  -------
# -------  Class: bottle           AP:   0.0817  -------
# -------  Class: bus              AP:   0.0598  -------
# -------  Class: car              AP:   0.2403  -------
# -------  Class: cat              AP:   0.1056  -------
# -------  Class: chair            AP:   0.2360  -------
# -------  Class: cow              AP:   0.0580  -------
# -------  Class: diningtable      AP:   0.1079  -------
# -------  Class: dog              AP:   0.1582  -------
# -------  Class: horse            AP:   0.1210  -------
# -------  Class: motorbike        AP:   0.0750  -------
# -------  Class: person           AP:   0.5032  -------
# -------  Class: pottedplant      AP:   0.0642  -------
# -------  Class: sheep            AP:   0.0836  -------
# -------  Class: sofa             AP:   0.1786  -------
# -------  Class: train            AP:   0.1563  -------
# -------  Class: tvmonitor        AP:   0.0957  -------
# mAP: 0.1495
# Avg loss: 0.21812161609530448

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5963356494903564
# -------  Class: aeroplane        AP:   0.0975  -------
# -------  Class: bicycle          AP:   0.0428  -------
# -------  Class: bird             AP:   0.0997  -------
# -------  Class: boat             AP:   0.1004  -------
# -------  Class: bottle           AP:   0.0425  -------
# -------  Class: bus              AP:   0.0290  -------
# -------  Class: car              AP:   0.1109  -------
# -------  Class: cat              AP:   0.0957  -------
# -------  Class: chair            AP:   0.1197  -------
# -------  Class: cow              AP:   0.0331  -------
# -------  Class: diningtable      AP:   0.0527  -------
# -------  Class: dog              AP:   0.1126  -------
# -------  Class: horse            AP:   0.0463  -------
# -------  Class: motorbike        AP:   0.0371  -------
# -------  Class: person           AP:   0.3469  -------
# -------  Class: pottedplant      AP:   0.0428  -------
# -------  Class: sheep            AP:   0.0375  -------
# -------  Class: sofa             AP:   0.0989  -------
# -------  Class: train            AP:   0.0404  -------
# -------  Class: tvmonitor        AP:   0.0487  -------
# mAP: 0.0818
# Avg loss: 0.27096573833157034
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.0817611725043644
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2586035430431366
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24563494324684143
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24345843493938446
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24299611151218414
# -------  Class: aeroplane        AP:   0.1026  -------
# -------  Class: bicycle          AP:   0.0463  -------
# -------  Class: bird             AP:   0.1141  -------
# -------  Class: boat             AP:   0.1048  -------
# -------  Class: bottle           AP:   0.0410  -------
# -------  Class: bus              AP:   0.0295  -------
# -------  Class: car              AP:   0.1124  -------
# -------  Class: cat              AP:   0.0927  -------
# -------  Class: chair            AP:   0.1192  -------
# -------  Class: cow              AP:   0.0347  -------
# -------  Class: diningtable      AP:   0.0526  -------
# -------  Class: dog              AP:   0.1160  -------
# -------  Class: horse            AP:   0.0478  -------
# -------  Class: motorbike        AP:   0.0373  -------
# -------  Class: person           AP:   0.3709  -------
# -------  Class: pottedplant      AP:   0.0458  -------
# -------  Class: sheep            AP:   0.0380  -------
# -------  Class: sofa             AP:   0.0948  -------
# -------  Class: train            AP:   0.0401  -------
# -------  Class: tvmonitor        AP:   0.0486  -------
# mAP: 0.0845
# Avg loss: 0.2374364949908911
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08446521978459029
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.23890094459056854
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.24235236644744873
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.24178077280521393
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.24052713811397552
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.24029415845870972
# -------  Class: aeroplane        AP:   0.0790  -------
# -------  Class: bicycle          AP:   0.0496  -------
# -------  Class: bird             AP:   0.1229  -------
# -------  Class: boat             AP:   0.0885  -------
# -------  Class: bottle           AP:   0.0416  -------
# -------  Class: bus              AP:   0.0299  -------
# -------  Class: car              AP:   0.1184  -------
# -------  Class: cat              AP:   0.0916  -------
# -------  Class: chair            AP:   0.1252  -------
# -------  Class: cow              AP:   0.0355  -------
# -------  Class: diningtable      AP:   0.0548  -------
# -------  Class: dog              AP:   0.1205  -------
# -------  Class: horse            AP:   0.0513  -------
# -------  Class: motorbike        AP:   0.0409  -------
# -------  Class: person           AP:   0.3816  -------
# -------  Class: pottedplant      AP:   0.0496  -------
# -------  Class: sheep            AP:   0.0459  -------
# -------  Class: sofa             AP:   0.0949  -------
# -------  Class: train            AP:   0.0416  -------
# -------  Class: tvmonitor        AP:   0.0496  -------
# mAP: 0.0856
# Avg loss: 0.2372804994092268
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.08564274821278846
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.23795926570892334
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.24077337980270386
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.23995086550712585
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.2383672446012497
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.24129587411880493
# -------  Class: aeroplane        AP:   0.0816  -------
# -------  Class: bicycle          AP:   0.0548  -------
# -------  Class: bird             AP:   0.1303  -------
# -------  Class: boat             AP:   0.0903  -------
# -------  Class: bottle           AP:   0.0393  -------
# -------  Class: bus              AP:   0.0321  -------
# -------  Class: car              AP:   0.1339  -------
# -------  Class: cat              AP:   0.0884  -------
# -------  Class: chair            AP:   0.1259  -------
# -------  Class: cow              AP:   0.0370  -------
# -------  Class: diningtable      AP:   0.0518  -------
# -------  Class: dog              AP:   0.1196  -------
# -------  Class: horse            AP:   0.0545  -------
# -------  Class: motorbike        AP:   0.0443  -------
# -------  Class: person           AP:   0.4643  -------
# -------  Class: pottedplant      AP:   0.0519  -------
# -------  Class: sheep            AP:   0.0471  -------
# -------  Class: sofa             AP:   0.0899  -------
# -------  Class: train            AP:   0.0446  -------
# -------  Class: tvmonitor        AP:   0.0504  -------
# mAP: 0.0916
# Avg loss: 0.2378414328776154
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.09160274487216293
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.23703347146511078
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.24034029245376587
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.2392210215330124
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.23857839405536652
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.23651613295078278
# -------  Class: aeroplane        AP:   0.1235  -------
# -------  Class: bicycle          AP:   0.0591  -------
# -------  Class: bird             AP:   0.1352  -------
# -------  Class: boat             AP:   0.1062  -------
# -------  Class: bottle           AP:   0.0459  -------
# -------  Class: bus              AP:   0.0359  -------
# -------  Class: car              AP:   0.1500  -------
# -------  Class: cat              AP:   0.0939  -------
# -------  Class: chair            AP:   0.1476  -------
# -------  Class: cow              AP:   0.0370  -------
# -------  Class: diningtable      AP:   0.0638  -------
# -------  Class: dog              AP:   0.1206  -------
# -------  Class: horse            AP:   0.0559  -------
# -------  Class: motorbike        AP:   0.0471  -------
# -------  Class: person           AP:   0.4921  -------
# -------  Class: pottedplant      AP:   0.0566  -------
# -------  Class: sheep            AP:   0.0472  -------
# -------  Class: sofa             AP:   0.0978  -------
# -------  Class: train            AP:   0.0547  -------
# -------  Class: tvmonitor        AP:   0.0513  -------
# mAP: 0.1011
# Avg loss: 0.23267892207585128
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.10107405114692555

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.0957  -------
# -------  Class: bicycle          AP:   0.0576  -------
# -------  Class: bird             AP:   0.1058  -------
# -------  Class: boat             AP:   0.0804  -------
# -------  Class: bottle           AP:   0.0469  -------
# -------  Class: bus              AP:   0.0344  -------
# -------  Class: car              AP:   0.1509  -------
# -------  Class: cat              AP:   0.0919  -------
# -------  Class: chair            AP:   0.1375  -------
# -------  Class: cow              AP:   0.0421  -------
# -------  Class: diningtable      AP:   0.0543  -------
# -------  Class: dog              AP:   0.1267  -------
# -------  Class: horse            AP:   0.0543  -------
# -------  Class: motorbike        AP:   0.0424  -------
# -------  Class: person           AP:   0.4963  -------
# -------  Class: pottedplant      AP:   0.0508  -------
# -------  Class: sheep            AP:   0.0562  -------
# -------  Class: sofa             AP:   0.1024  -------
# -------  Class: train            AP:   0.0610  -------
# -------  Class: tvmonitor        AP:   0.0499  -------
# mAP: 0.0969
# Avg loss: 0.22876422107219696
# Test mAP:  0.0968737684254131

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.21782617270946503
# -------  Class: aeroplane        AP:   0.7550  -------
# -------  Class: bicycle          AP:   0.5764  -------
# -------  Class: bird             AP:   0.8036  -------
# -------  Class: boat             AP:   0.6430  -------
# -------  Class: bottle           AP:   0.2712  -------
# -------  Class: bus              AP:   0.4678  -------
# -------  Class: car              AP:   0.7606  -------
# -------  Class: cat              AP:   0.7232  -------
# -------  Class: chair            AP:   0.5996  -------
# -------  Class: cow              AP:   0.2831  -------
# -------  Class: diningtable      AP:   0.4667  -------
# -------  Class: dog              AP:   0.6371  -------
# -------  Class: horse            AP:   0.6274  -------
# -------  Class: motorbike        AP:   0.6443  -------
# -------  Class: person           AP:   0.9051  -------
# -------  Class: pottedplant      AP:   0.2466  -------
# -------  Class: sheep            AP:   0.3364  -------
# -------  Class: sofa             AP:   0.4798  -------
# -------  Class: train            AP:   0.8127  -------
# -------  Class: tvmonitor        AP:   0.5291  -------
# mAP: 0.5784
# Avg loss: 0.1360381832894157
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.578445698844988
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.11528617888689041
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.1072930172085762
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.09984055161476135
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.08901243656873703
# -------  Class: aeroplane        AP:   0.8475  -------
# -------  Class: bicycle          AP:   0.6605  -------
# -------  Class: bird             AP:   0.8560  -------
# -------  Class: boat             AP:   0.7555  -------
# -------  Class: bottle           AP:   0.4154  -------
# -------  Class: bus              AP:   0.6223  -------
# -------  Class: car              AP:   0.8179  -------
# -------  Class: cat              AP:   0.8098  -------
# -------  Class: chair            AP:   0.6255  -------
# -------  Class: cow              AP:   0.4845  -------
# -------  Class: diningtable      AP:   0.5880  -------
# -------  Class: dog              AP:   0.7097  -------
# -------  Class: horse            AP:   0.7291  -------
# -------  Class: motorbike        AP:   0.7370  -------
# -------  Class: person           AP:   0.9129  -------
# -------  Class: pottedplant      AP:   0.4317  -------
# -------  Class: sheep            AP:   0.6614  -------
# -------  Class: sofa             AP:   0.5539  -------
# -------  Class: train            AP:   0.9023  -------
# -------  Class: tvmonitor        AP:   0.6317  -------
# mAP: 0.6876
# Avg loss: 0.11963834087638293
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.687620247582905
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.08144176751375198
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.07695772498846054
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.06469042599201202
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.054655011743307114
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.04816049709916115
# -------  Class: aeroplane        AP:   0.8645  -------
# -------  Class: bicycle          AP:   0.7028  -------
# -------  Class: bird             AP:   0.8471  -------
# -------  Class: boat             AP:   0.7368  -------
# -------  Class: bottle           AP:   0.4182  -------
# -------  Class: bus              AP:   0.5959  -------
# -------  Class: car              AP:   0.8187  -------
# -------  Class: cat              AP:   0.7909  -------
# -------  Class: chair            AP:   0.6115  -------
# -------  Class: cow              AP:   0.5106  -------
# -------  Class: diningtable      AP:   0.5897  -------
# -------  Class: dog              AP:   0.7176  -------
# -------  Class: horse            AP:   0.7496  -------
# -------  Class: motorbike        AP:   0.7879  -------
# -------  Class: person           AP:   0.9100  -------
# -------  Class: pottedplant      AP:   0.4644  -------
# -------  Class: sheep            AP:   0.6355  -------
# -------  Class: sofa             AP:   0.5404  -------
# -------  Class: train            AP:   0.8828  -------
# -------  Class: tvmonitor        AP:   0.6054  -------
# mAP: 0.6890
# Avg loss: 0.13185299202507617
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.6890093301914502
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.04338327422738075
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.03418523445725441
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.03626975417137146
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.03039841167628765
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.028407346457242966
# -------  Class: aeroplane        AP:   0.8582  -------
# -------  Class: bicycle          AP:   0.6935  -------
# -------  Class: bird             AP:   0.8458  -------
# -------  Class: boat             AP:   0.7296  -------
# -------  Class: bottle           AP:   0.4024  -------
# -------  Class: bus              AP:   0.5859  -------
# -------  Class: car              AP:   0.8158  -------
# -------  Class: cat              AP:   0.7443  -------
# -------  Class: chair            AP:   0.6056  -------
# -------  Class: cow              AP:   0.5076  -------
# -------  Class: diningtable      AP:   0.5780  -------
# -------  Class: dog              AP:   0.7044  -------
# -------  Class: horse            AP:   0.7475  -------
# -------  Class: motorbike        AP:   0.7906  -------
# -------  Class: person           AP:   0.9033  -------
# -------  Class: pottedplant      AP:   0.4500  -------
# -------  Class: sheep            AP:   0.6044  -------
# -------  Class: sofa             AP:   0.5206  -------
# -------  Class: train            AP:   0.8931  -------
# -------  Class: tvmonitor        AP:   0.6356  -------
# mAP: 0.6808
# Avg loss: 0.1539145199691548
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.6808183839999341
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.03392120078206062
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.020707780495285988
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.020375898107886314
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.01677802950143814
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.014255727641284466
# -------  Class: aeroplane        AP:   0.8562  -------
# -------  Class: bicycle          AP:   0.6893  -------
# -------  Class: bird             AP:   0.8416  -------
# -------  Class: boat             AP:   0.7233  -------
# -------  Class: bottle           AP:   0.4011  -------
# -------  Class: bus              AP:   0.5995  -------
# -------  Class: car              AP:   0.8153  -------
# -------  Class: cat              AP:   0.7724  -------
# -------  Class: chair            AP:   0.5891  -------
# -------  Class: cow              AP:   0.4793  -------
# -------  Class: diningtable      AP:   0.5885  -------
# -------  Class: dog              AP:   0.7005  -------
# -------  Class: horse            AP:   0.7624  -------
# -------  Class: motorbike        AP:   0.7866  -------
# -------  Class: person           AP:   0.9048  -------
# -------  Class: pottedplant      AP:   0.4282  -------
# -------  Class: sheep            AP:   0.6080  -------
# -------  Class: sofa             AP:   0.5325  -------
# -------  Class: train            AP:   0.8859  -------
# -------  Class: tvmonitor        AP:   0.6365  -------
# mAP: 0.6801
# Avg loss: 0.17936085646643357
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6800545811227455

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8598  -------
# -------  Class: bicycle          AP:   0.7400  -------
# -------  Class: bird             AP:   0.8343  -------
# -------  Class: boat             AP:   0.7953  -------
# -------  Class: bottle           AP:   0.3379  -------
# -------  Class: bus              AP:   0.6685  -------
# -------  Class: car              AP:   0.8277  -------
# -------  Class: cat              AP:   0.7633  -------
# -------  Class: chair            AP:   0.5740  -------
# -------  Class: cow              AP:   0.4763  -------
# -------  Class: diningtable      AP:   0.6396  -------
# -------  Class: dog              AP:   0.7339  -------
# -------  Class: horse            AP:   0.8362  -------
# -------  Class: motorbike        AP:   0.7657  -------
# -------  Class: person           AP:   0.9164  -------
# -------  Class: pottedplant      AP:   0.4392  -------
# -------  Class: sheep            AP:   0.6448  -------
# -------  Class: sofa             AP:   0.5096  -------
# -------  Class: train            AP:   0.8760  -------
# -------  Class: tvmonitor        AP:   0.6283  -------
# mAP: 0.6933
# Avg loss: 0.17666261702775954
# Test mAP:  0.6933413945855392
